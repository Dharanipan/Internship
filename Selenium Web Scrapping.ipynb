# %% [markdown]
# !pip install selenium

# %%
import selenium
from selenium import webdriver
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
from selenium.webdriver.common.by import By
import time

# %%
# 1. Write a python program to scrape data for “Data Analyst” Job position in “Bangalore” location. You 
# have to scrape the job-title, job-location, company_name, experience_required. You have to scrape first 10 
# jobs data.

driver=webdriver.Chrome(r"chromedriver.exe")

# %%
driver.get("https://www.naukri.com/")

# %%
designation=driver.find_element(By.CLASS_NAME,"suggestor-input")
designation.send_keys("Data Analyst")

# %%
location=driver.find_element(By.XPATH,'/html/body/div[1]/div[6]/div/div/div[5]/div/div/div/input')
location.send_keys("Bangalore")

# %%
search=driver.find_element(By.XPATH,'/html/body/div[1]/div[6]/div/div/div[6]')
search.click()

# %%
job_title=[]
job_location=[]
company_name=[]
experience_required=[]

# %%
title_tags=driver.find_elements(By.XPATH,'//a[@class="title ellipsis"]')
for i in title_tags[0:10]:
    title=i.text
    job_title.append(title)

# %%
location_tags=driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft locWdth"]')
for i in location_tags[0:10]:
    location=i.text
    job_location.append(location)

# %%
company_tags=driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')
for i in company_tags[0:10]:
    company=i.text
    company_name.append(company)

# %%
experience_tags=driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft expwdth"]')
for i in experience_tags[0:10]:
    experience=i.text
    experience_required.append(experience)

# %%
print(len(job_title),len(job_location),len(company_name),len(experience_required))
# Out:
# 10 10 10 10

# %%
df1=pd.DataFrame({'Job title':job_title,'Job Location':job_location,'Company Name':company_name,'Experience Required':experience_required})
df1
# Out:
#                           Job title  \
# 0                      Data Analyst
# 1                      Data Analyst
# 2                      Data Analyst
# 3           Data Analyst Databricks
# 4                      Data Analyst
# 5                      Data Analyst
# 6                      Data Analyst
# 7    Required Data Analyst Off Role
# 8  Data Analyst | Google App Script
# 9             Data Analyst - EdTech
#
#                                         Job Location  \
# 0                                Bangalore/Bengaluru
# 1  Hybrid - Bangalore/Bengaluru, Hyderabad/Secund...
# 2                                Bangalore/Bengaluru
# 3                                Bangalore/Bengaluru
# 4                                Bangalore/Bengaluru
# 5          Hybrid - Bangalore/Bengaluru, Delhi / NCR
# 6                                Bangalore/Bengaluru
# 7                                Bangalore/Bengaluru
# 8                        Bangalore/Bengaluru, Mumbai
# ...

# %%
# 2. Write a python program to scrape data for “Data Scientist” Job position in “Bangalore” location. You 
# have to scrape the job-title, job-location, company_name. You have to scrape first 10 jobs data.
# This task will be done in following steps:

driver2=webdriver.Chrome(r"chromedriver.exe")
driver2.get("https://www.naukri.com/")

# %%
designation2=driver2.find_element(By.CLASS_NAME,"suggestor-input")
designation2.send_keys("Data Scientist")

# %%
location2=driver2.find_element(By.XPATH,'/html/body/div[1]/div[6]/div/div/div[5]/div/div/div/input')
location2.send_keys("Bangalore")

# %%
search2=driver2.find_element(By.XPATH,'/html/body/div[1]/div[6]/div/div/div[6]')
search2.click()

# %%
job_title2=[]
job_location2=[]
company_name2=[]

# %%
titletag2=driver2.find_elements(By.XPATH,'//a[@class="title ellipsis"]')
for i in titletag2[0:10]:
    title2=i.text
    job_title2.append(title2)

# %%
locationtags2=driver2.find_elements(By.XPATH,'//span[@class="ellipsis fleft locWdth"]')
for i in locationtags2[0:10]:
    job_location2.append(i.text)

# %%
companytags2=driver2.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')
for i in companytags2[0:10]:
    company_name2.append(i.text)

# %%
df2=pd.DataFrame({'Job Title':job_title2,'Job Location':job_location2,'Company Name':company_name2})
df2
# Out:
#                                  Job Title  \
# 0                  Data Science Specialist
# 1         Analystics & Modeling Specialist
# 2                           Data Scientist
# 3                       Sr. Data scientist
# 4                           Data Scientist
# 5                      Lead Data Scientist
# 6                    Expert Data Scientist
# 7                       Sr. Data Scientist
# 8  Lead Artificial Intelligence Specialist
# 9                      Lead data scientist
#
#                                         Job Location  \
# 0  Bangalore/Bengaluru, Kolkata, Mumbai, Hyderaba...
# 1  Bangalore/Bengaluru, Kolkata, Mumbai, Hyderaba...
# 2  Hybrid - Bangalore/Bengaluru, Kolkata, Hyderab...
# 3  Bangalore/Bengaluru, Hyderabad/Secunderabad, M...
# 4  Bangalore/Bengaluru, Noida, Kolkata, Mumbai, H...
# 5  Bangalore/Bengaluru, Noida, Hyderabad/Secunder...
# 6                        Bangalore/Bengaluru, Mumbai
# 7                                Bangalore/Bengaluru
# ...

# %%
#3. You have to use the location and salary filter.
# You have to scrape data for “Data Scientist” designation for first 10 job results. 
# You have to scrape the job-title, job-location, company name, experience required.
# The location filter to be used is “Delhi/NCR”. The salary filter to be used is “3-6” lakhs

driver3=webdriver.Chrome(r"chromedriver.exe")
driver3.get("https://www.naukri.com/")

# %%
designation3=driver3.find_element(By.CLASS_NAME,"suggestor-input")
designation3.send_keys("Data Scientist")

# %%
search3=driver3.find_element(By.XPATH,'/html/body/div[1]/div[6]/div/div/div[6]')
search3.click()

# %%
location3=driver3.find_element(By.XPATH,'/html/body/div[1]/div[4]/div/div/section[1]/div[2]/div[5]/div[2]/div[2]/label/p/span[1]')
location3.click()

# %%
salary3=driver3.find_element(By.XPATH,'/html/body/div[1]/div[4]/div/div/section[1]/div[2]/div[6]/div[2]/div[2]/label/p/span[1]')
salary3.click()

# %%
job_title3=[]
job_location3=[]
company_name3=[]
experience_required3=[]

# %%
titletags3=driver3.find_elements(By.XPATH,'//a[@class="title ellipsis"]')
for i in titletags3[0:10]:
    title3=i.text
    job_title3.append(title3)

# %%
locationtags3=driver3.find_elements(By.XPATH,'//span[@class="ellipsis fleft locWdth"]')
for i in locationtags3[0:10]:
    job_location3.append(i.text)

# %%
companytags3=driver3.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')
for i in companytags3[0:10]:
    company_name3.append(i.text)

# %%
experiencetags3=driver3.find_elements(By.XPATH,'//span[@class="ellipsis fleft expwdth"]')
for i in experiencetags3[0:10]:
    experience_required3.append(i.text)

# %%
print(len(job_title3),len(job_location3),len(company_name3),len(experience_required3))
# Out:
# 10 10 10 10

# %%
df3=pd.DataFrame({'Job Title':job_title3,'Job Location':job_location3,'Company Name':company_name3,'Experience Required':experience_required3})
df3
# Out:
#                              Job Title  \
# 0          Data Scientist data Analyst
# 1    Data Scientist - Engine Algorithm
# 2                 Analyst-Data Science
# 3                 Analyst-Data Science
# 4   Senior Data Scientist - Statistics
# 5                       Data Scientist
# 6                       Data Scientist
# 7  Associate Data Scientist - ML & NLP
# 8                       Data Scientist
# 9                       Data Scientist
#
#                                         Job Location  \
# 0  Delhi / NCR, Kolkata, Hyderabad/Secunderabad, ...
# 1  Delhi / NCR, Kolkata, Mumbai, Hyderabad/Secund...
# 2                                   Gurgaon/Gurugram
# 3                                   Gurgaon/Gurugram
# 4                                   Gurgaon/Gurugram
# 5  Delhi / NCR, Noida(Sector-136 Noida), Ghaziaba...
# 6                                   Gurgaon/Gurugram
# 7                                   Gurgaon/Gurugram
# ...

# %%
#4. Scrape data of first 100 sunglasses listings on flipkart.com. You have to scrape four attributes:
# 1. Brand
# 2. ProductDescription
# 3. Price

driver4=webdriver.Chrome(r"chromedriver.exe")
driver4.get("https://www.flipkart.com/")

# %%
searchdata=driver4.find_element(By.XPATH,'/html/body/div[1]/div/div[1]/div[1]/div[2]/div[2]/form/div/div/input')
searchdata.send_keys('sunglasses')

# %%
search4=driver4.find_element(By.XPATH,'/html/body/div[1]/div/div[1]/div[1]/div[2]/div[2]/form/div/button')
search4.click()

# %%
brand4=[]
product_description4=[]
discount_prize4=[]
actual_prize4=[]

# %%
for i in driver4.find_elements(By.XPATH,'//div[@class="_2WkVRV"]'):
    brand4.append(i.text)

# %%
for i in driver4.find_elements(By.XPATH,'//a[@class="IRpwTa"]'):
    product_description4.append(i.text)

# %%
for i in driver4.find_elements(By.XPATH,'//div[@class="_30jeq3"]'):
    discount_prize4.append(i.text)

# %%
for i in driver4.find_elements(By.XPATH,'//div[@class="_3I9_wc"]'):
    actual_prize4.append(i.text)

# %%
next_button=driver4.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[1]/div[2]/div[12]/div/div/nav/a[11]')
next_button.click()

# %%
for i in driver4.find_elements(By.XPATH,'//div[@class="_2WkVRV"]'):
    brand4.append(i.text)

# %%
for i in driver4.find_elements(By.XPATH,'//a[@class="IRpwTa"]'):
    product_description4.append(i.text)

# %%
for i in driver4.find_elements(By.XPATH,'//div[@class="_30jeq3"]'):
    discount_prize4.append(i.text)

# %%
for i in driver4.find_elements(By.XPATH,'//div[@class="_3I9_wc"]'):
    actual_prize4.append(i.text)

# %%
next_button=driver4.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[1]/div[2]/div[12]/div/div/nav/a[12]/span')
next_button.click()

# %%
brandtags4=driver4.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
for i in brandtags4[0:20]:
    brand4.append(i.text)

# %%
producttags4=driver4.find_elements(By.XPATH,'//a[@class="IRpwTa"]')
for i in producttags4[0:20]:
    product_description4.append(i.text)

# %%
discountprizetags4=driver4.find_elements(By.XPATH,'//div[@class="_30jeq3"]')
for i in discountprizetags4[0:20]:
    discount_prize4.append(i.text)

# %%
actualprizetags4=driver4.find_elements(By.XPATH,'//div[@class="_3I9_wc"]')
for i in actualprizetags4[0:20]:
    actual_prize4.append(i.text)

# %%
print(len(brand4),len(product_description4),len(discount_prize4),len(actual_prize4))
# Out:
# 100 100 100 100

# %%
df4=pd.DataFrame({'Brand':brand4,'Product Descripition':product_description4,'Discount Prize':discount_prize4,'Actual Prize':actual_prize4})
df4
# Out:
#              Brand                               Product Descripition  \
# 0    VINCENT CHASE     Polarized, UV Protection Round Sunglasses (50)
# 1    VINCENT CHASE  by Lenskart Polarized, UV Protection Retro Squ...
# 2             SRPM             UV Protection Wayfarer Sunglasses (50)
# 3        Elligator                UV Protection Round Sunglasses (53)
# 4         Fastrack   UV Protection Rectangular Sunglasses (Free Size)
# ..             ...                                                ...
# 95    Singco India  UV Protection, Riding Glasses Retro Square, Re...
# 96  ROZZETTA CRAFT  UV Protection, Gradient Round Sunglasses (Free...
# 97           NuVew    UV Protection, Mirrored Aviator Sunglasses (57)
# 98        Poloport      UV Protection Wayfarer Sunglasses (Free Size)
# 99    Singco India  UV Protection, Riding Glasses Retro Square, Re...
#
#    Discount Prize Actual Prize
# 0            ₹829       ₹1,999
# 1            ₹999       ₹1,999
# ...

# %%
#5. Scrape 100 reviews data from flipkart.com for iphone11 phone. You have to go the link: 
# https://www.flipkart.com/apple-iphone-11-black-64-gb/productreviews/itm4e5041ba101fd?pid=MOBFWQ6BXGJCEYNY&lid=LSTMOBFWQ6BXGJCEYNYZXSHRJ&market 
# place=FLIPKART

driver5=webdriver.Chrome(r"chromedriver.exe")
driver5.get("https://www.flipkart.com/apple-iphone-11-black-64-gb/product-reviews/itm4e5041ba101fd?pid=MOBFWQ6BXGJCEYNY&lid=LSTMOBFWQ6BXGJCEYNYZXSHRJ&marketplace=FLIPKART")

# %%
ratings5=[]
start=0
end=10
for page5 in range(start,end):
    ratingstags5=driver5.find_elements(By.XPATH,'//div[@class="_3LWZlK _1BLPMq"]')
    for i in ratingstags5:
        ratings5.append(i.text)
next_button5=driver5.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div/div/div[2]/div[13]/div/div/nav/a[11]/span')
next_button5.click()
time.sleep(15)

# %%
review_summary5=[]
start=0
end=10
for page5 in range(start,end):
    reviewsummarytags5=driver5.find_elements(By.XPATH,'//p[@class="_2-N8zT"]')
    for i in reviewsummarytags5:
        review_summary5.append(i.text)
next_button5=driver5.find_element(By.XPATH,'/html/body/div/div/div[3]/div/div/div[2]/div[13]/div/div/nav/a[11]/span')
next_button5.click()
time.sleep(15)

# %%
previous_button5=driver5.find_element(By.XPATH,'/html/body/div/div/div[3]/div/div/div[2]/div[13]/div/div/nav/a[1]/span')
previous_button5.click()

# %%
full_review5=[]
start=0
end=10
for page5 in range(start,end):
    fullreviewtags5=driver5.find_elements(By.XPATH,'//div[@class="t-ZTKy"]')
    for i in fullreviewtags5:
        full_review5.append(i.text.replace('\n',''))
next_button5=driver5.find_element(By.XPATH,'/html/body/div/div/div[3]/div/div/div[2]/div[13]/div/div/nav/a[11]/span')
next_button5.click()
time.sleep(15)

# %%
df5=pd.DataFrame({'Ratings':ratings5,'Review Summary':review_summary5,'Full Review':full_review5})
df5
# Out:
#    Ratings       Review Summary  \
# 0        5       Simply awesome
# 1        5     Perfect product!
# 2        5  Best in the market!
# 3        4      Value-for-money
# 4        5   Highly recommended
# ..     ...                  ...
# 95       5    Worth every penny
# 96       5     Perfect product!
# 97       5   Highly recommended
# 98       4          Pretty good
# 99       5        Great product
#
#                                           Full Review
# 0   Really satisfied with the Product I received.....
# 1   Amazing phone with great cameras and better ba...
# 2   Great iPhone very snappy experience as apple k...
# 3   I'm Really happy with the productDelivery was ...
# 4   It's my first time to use iOS phone and I am l...
# ..                                                ...
# 95  Previously I was using one plus 3t it was a gr...
# 96  Value for money5 star ratingExcellent cameraBa...
# 97  What a camera .....just awesome ..you can feel...
# ...

# %%
#6. Scrape data for first 100 sneakers you find when you visit flipkart.com and search for “sneakers” in the 
# search field.
# You have to scrape 3 attributes of each sneaker:
# 1. Brand
# 2. ProductDescription
# 3. Price

driver6=webdriver.Chrome(r"chromedriver.exe")
driver6.get("https://www.flipkart.com/")

# %%
cancel_button6=driver6.find_element(By.XPATH,'/html/body/div[2]/div/div/button')
cancel_button6.click()

# %%
searchdata6=driver6.find_element(By.XPATH,'/html/body/div[1]/div/div[1]/div[1]/div[2]/div[2]/form/div/div/input')
searchdata6.send_keys('sneakers')

# %%
search_button6=driver6.find_element(By.XPATH,'/html/body/div[1]/div/div[1]/div[1]/div[2]/div[2]/form/div/button')
search_button6.click()

# %%
brand6=[]
start=0
end=2
for page6 in range(start,end):
    brandtags6=driver6.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
    for i in brandtags6:
        brand6.append(i.text)
next_button6=driver6.find_element(By.XPATH,'//a[@class="_1LKTO3"]')
next_button6.click()
time.sleep(15)

# %%
previous_button6=driver6.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[1]/div[2]/div[12]/div/div/nav/a[1]/span')
previous_button6.click()

# %%
product_description6=[]
start=0
end=2
for page6 in range(start,end):
    pdesctags6=driver6.find_elements(By.XPATH,'//a[@class="IRpwTa"]')
    for i in pdesctags6:
        product_description6.append(i.text)
next_button6=driver6.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[1]/div[2]/div[12]/div/div/nav/a[11]/span')
next_button6.click()
time.sleep(15)

# %%
previous_button6=driver6.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[1]/div[2]/div[12]/div/div/nav/a[1]/span')
previous_button6.click()

# %%
prize6=[]
start=0
end=2
for page6 in range(start,end):
    prizetags6=driver6.find_elements(By.XPATH,'//div[@class="_30jeq3"]')
    for i in prizetags6:
        prize6.append(i.text)
next_button6=driver6.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[1]/div[2]/div[12]/div/div/nav/a[11]/span')
next_button6.click()
time.sleep(15)

# %%
next_button6=driver6.find_element(By.XPATH,'/html/body/div[1]/div/div[3]/div[1]/div[2]/div[12]/div/div/nav/a[12]')
next_button6.click()

# %%
for i in driver6.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')[0:20]:
    brand6.append(i.text)

# %%
for i in driver6.find_elements(By.XPATH,'//a[@class="IRpwTa"]')[0:20]:
    product_description6.append(i.text)

# %%
for i in driver6.find_elements(By.XPATH,'//div[@class="_30jeq3"]')[0:20]:
    prize6.append(i.text)

# %%
df6=pd.DataFrame({'Brand':brand6,'Product Description':product_description6,'Prize':prize6})
df6
# Out:
#          Brand                                Product Description Prize
# 0        BIRDE  Premium Casual Shoes For Women Sneakers For Women  ₹299
# 1     HOTSTYLE                              CR-1 Sneakers For Men  ₹258
# 2        BIRDE      Combo Pack of 2 Casual Shoes Sneakers For Men  ₹549
# 3     BERSACHE  Combo pack of 2 casual shoes for men Sneakers ...  ₹499
# 4       Shozie  Stylish Sneakers Shoes for Women And Girls Sne...  ₹399
# ..         ...                                                ...   ...
# 95          TR                                   Sneakers For Men  ₹699
# 96      Kraasa                                 Sneakers For Women  ₹299
# 97  HIGHLANDER                                   Sneakers For Men  ₹796
# 98      Labbin                                   Sneakers For Men  ₹444
# 99        aadi  Synthetic Leather |Lightweight|Comfort|Summer|...  ₹399
#
# [100 rows x 3 columns]

# %%
#7. Go to webpage https://www.amazon.in/ Enter “Laptop” in the search field and then click the search icon. Then 
# set CPU Type filter to “Intel Core i7” as shown in the below image:

driver7=webdriver.Chrome(r"chromedriver.exe")
driver7.get("https://www.amazon.in/")

# %%
searchdata7=driver7.find_element(By.XPATH,'/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[2]/div[1]/input')
searchdata7.send_keys('Laptop')

# %%
search_button7=driver7.find_element(By.XPATH,'/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[3]/div')
search_button7.click()

# %%
filter7=driver7.find_element(By.XPATH,'/html/body/div[1]/div[2]/div[1]/div[2]/div/div[3]/span/div[1]/div/div/div[6]/ul[6]/li[10]/span/a/span')
filter7.click()

# %%
title7=[]
for i in driver7.find_elements(By.XPATH,'//span[@class="a-size-medium a-color-base a-text-normal"]')[0:10]:
    title7.append(i.text)

# %%
ratings7=[]
for i in driver7.find_elements(By.XPATH,'//span[@class="a-size-base"]')[0:10]:
    ratings7.append(i.text)

# %%
prize7=[]
for i in driver7.find_elements(By.XPATH,'//span[@class="a-price-whole"]')[0:10]:
    prize7.append(i.text)

# %%
print(len(title7),len(ratings7),len(prize7))
# Out:
# 10 10 10

# %%
df7=pd.DataFrame({'Title':title7,'Ratings':ratings7,'Prize':prize7})
df7
# Out:
#                                                Title Ratings   Prize
# 0  ASUS Vivobook 14, Intel Core i7-1165G7 11th Ge...     4.1  56,990
# 1  HP Victus Gaming Latest 12th Gen Intel Core i7...     4.3  85,990
# 2  Dell Inspiron 5320 Laptop, Intel i7-1260P, 16G...     3.6  84,918
# 3  HP Pavilion Plus, 12th Gen Intel Core i7 16GB ...     4.0  94,490
# 4  Lenovo IdeaPad Slim 5 12th Gen Intel Core i7 1...     4.2  78,490
# 5  Samsung Galaxy Book2 (NP750) Intel 12th Gen co...     4.0  82,990
# 6  Acer Nitro 5 Gaming Laptop Intel core i7 11th ...     4.0  77,990
# 7  MSI GF75 Thin Gaming, Intel Core i7-10750H, 44...     4.4  82,990
# 8  HP Pavilion 14 12th Gen Intel Core i7 16GB SDR...     4.3  62,990
# 9  ASUS Vivobook 15, 15.6-inch (39.62 cms) FHD, I...     4.1  88,025

# %%
#8. Write a python program to scrape data for Top 1000 Quotes of All Time.
driver8=webdriver.Chrome(r"chromedriver.exe")
driver8.get("https://www.azquotes.com/")

# %%
top_quotes8=driver8.find_element(By.XPATH,'/html/body/div[1]/div[1]/div[1]/div/div[3]/ul/li[5]/a')
top_quotes8.click()

# %%
quote8=[]
start=0
end=10
for page8 in range(start,end):
    quotetags8=driver8.find_elements(By.XPATH,'//a[@class="title"]')
    for i in quotetags8:
        quote8.append(i.text)
next_button8=driver8.find_element(By.XPATH,'/html/body/div[1]/div[2]/div/div/div/div[1]/div/div[4]/li[12]/a')
next_button8.click()
time.sleep(20)

# %%
first8=driver8.find_element(By.XPATH,'/html/body/div[1]/div[2]/div/div/div/div[1]/div/div[4]/li[1]/a')
first8.click()

# %%
author8=[]
start=0
end=10
for page8 in range(start,end):
    authortags8=driver8.find_elements(By.XPATH,'//div[@class="author"]')
    for i in authortags8:
        author8.append(i.text)
next_button8=driver8.find_element(By.XPATH,'/html/body/div[1]/div[2]/div/div/div/div[1]/div/div[4]/li[12]/a')
next_button8.click()
time.sleep(20)

# %%
first8=driver8.find_element(By.XPATH,'/html/body/div[1]/div[2]/div/div/div/div[1]/div/div[4]/li[1]/a')
first8.click()

# %%
type_of_quotes8=[]
start=0
end=10
for page8 in range(start,end):
    typeofquotestags8=driver8.find_elements(By.XPATH,'//div[@class="tags"]')
    for i in typeofquotestags8:
        type_of_quotes8.append(i.text)
next_button8=driver8.find_element(By.XPATH,'/html/body/div[1]/div[2]/div/div/div/div[1]/div/div[4]/li[12]/a')
next_button8.click()
time.sleep(20)

# %%
print(len(quote8),len(author8),len(type_of_quotes8))
# Out:
# 1000 1000 1000

# %%
df8=pd.DataFrame({'Quote':quote8,'Author':author8,'Type of Quotes':type_of_quotes8})
df8
# Out:
#                                                  Quote                Author  \
# 0    The essence of strategy is choosing what not t...        Michael Porter
# 1    One cannot and must not try to erase the past ...            Golda Meir
# 2    Patriotism means to stand by the country. It d...    Theodore Roosevelt
# 3    Death is something inevitable. When a man has ...        Nelson Mandela
# 4    You have to love a nation that celebrates its ...          Erma Bombeck
# ..                                                 ...                   ...
# 995     When the going gets weird, the weird turn pro.    Hunter S. Thompson
# 996  When a train goes through a tunnel and it gets...       Corrie Ten Boom
# 997  If you think you are too small to make a diffe...            Dalai Lama
# 998  God doesn't require us to succeed, he only req...         Mother Teresa
# 999    Change your thoughts and you change your world.  Norman Vincent Peale
#
#                             Type of Quotes
# ...

# %%
# 9. Write a python program to display list of respected former Prime Ministers of India(i.e. Name, Born-Dead, 
# Term of office, Remarks) from https://www.jagranjosh.com/.

driver9=webdriver.Chrome(r"chromedriver.exe")
driver9.get("https://www.jagranjosh.com/")

# %%
gk9=driver9.find_element(By.XPATH,'/html/body/div/div[1]/div/div[1]/div/div[6]/div/div[1]/header/div[3]/ul/li[9]/a')
gk9.click()

# %%
prime_minister9=driver9.find_element(By.XPATH,'/html/body/div[1]/div/div/div[2]/div/div[10]/div/div/ul/li[2]/a')
prime_minister9.click()

# %%
born_dead9=[]
born_deadtags9=driver9.find_elements(By.XPATH,'//div[@class="table-box"]/table/tbody/tr/td[3]/p')
for i in born_deadtags9[0:18]:
    born_dead9.append(i.text)

# %%
name9=[]
nametags9=driver9.find_elements(By.XPATH,'//div[@class="table-box"]/table/tbody/tr/td[2]')
for i in nametags9[0:18]:
    name9.append(i.text)

# %%
term_of_office9=[]
term_of_officetags9=driver9.find_elements(By.XPATH,'//div[@class="table-box"]/table/tbody/tr/td[4]')
for i in term_of_officetags9[0:18]:
    term_of_office9.append(i.text.replace('\n','  '))

# %%
remarks9=[]
remarkstags9=driver9.find_elements(By.XPATH,'//div[@class="table-box"]/table/tbody/tr/td[5]')
for i in remarkstags9[0:18]:
    remarks9.append(i.text)

# %%
print(len(name9),len(born_dead9),len(term_of_office9),len(remarks9))
# Out:
# 18 18 18 18

# %%
df9=pd.DataFrame({'Name':name9,'Born-Dead':born_dead9,'Term of Office':term_of_office9,'Remarks':remarks9})
df9
# Out:
#                            Name     Born-Dead  \
# 0             Jawahar Lal Nehru   (1889–1964)
# 1     Gulzarilal Nanda (Acting)   (1898-1998)
# 2           Lal Bahadur Shastri   (1904–1966)
# 3   Gulzari Lal Nanda  (Acting)   (1898-1998)
# 4                 Indira Gandhi   (1917–1984)
# 5                 Morarji Desai   (1896–1995)
# 6                  Charan Singh   (1902–1987)
# 7                 Indira Gandhi   (1917–1984)
# 8                  Rajiv Gandhi   (1944–1991)
# 9                   V. P. Singh   (1931–2008)
# 10              Chandra Shekhar   (1927–2007)
# 11          P. V. Narasimha Rao   (1921–2004)
# 12         Atal Bihari Vajpayee  (1924- 2018)
# 13             H. D. Deve Gowda   (born 1933)
# 14           Inder Kumar Gujral   (1919–2012)
# 15         Atal Bihari Vajpayee   (1924-2018)
# 16               Manmohan Singh   (born 1932)
# 17                Narendra Modi   (born 1950)
#
#                                        Term of Office  \
# ...

# %%
#10. Write a python program to display list of 50 Most expensive cars in the world (i.e. 
# Car name and Price) from https://www.motor1.com/

driver10=webdriver.Chrome(r"chromedriver.exe")
driver10.get("https://www.motor1.com/")

# %%
list_option10=driver10.find_element(By.XPATH,'/html/body/div[3]/div[2]/div/div/div[1]/div')
list_option10.click()

# %%
features10=driver10.find_element(By.XPATH,'/html/body/div[4]/div[1]/div[3]/ul/li[5]/a')
features10.click()

# %%
expensive_cars50=driver10.find_element(By.XPATH,'/html/body/div[3]/div[7]/div/div[1]/div[1]/div[2]/div/div[1]/h3/a')
expensive_cars50.click()

# %%
car_name10=[]
for i in driver10.find_elements(By.XPATH,'//h3[@class="subheader"]')[0:50]:
    car_name10.append(i.text)

# %%
prize10=[]
for i in driver10.find_elements(By.TAG_NAME,'strong')[0:50]:
    prize10.append(i.text.replace("Price:",''))

# %%
print(len(car_name10),len(prize10))
# Out:
# 50 50

# %%
df10=pd.DataFrame({'Car Name':car_name10,'Prize':prize10})
df10
# Out:
#                            Car Name           Prize
# 0                     De Tomaso P72    $1.3 Million
# 1                 Ferrari LaFerrari    $1.4 Million
# 2                     Pagani Huayra    $1.4 Million
# 3                      McLaren Elva
# 4                       Czinger 21C    $1.7 Million
# 5                     Ferrari Monza    $1.7 Million
# 6                Gordon Murray T.33    $1.7 Million
# 7                 Koenigsegg Gemera    $1.7 Million
# 8                       Zenvo TSR-S    $1.7 Million
# 9                Hennessey Venom F5    $1.7 Million
# 10                  Bentley Bacalar    $1.8 Million
# 11    Hispano Suiza Carmen Boulogne    $1.9 Million
# 12           Bentley Mulliner Batur    $1.9 Million
# 13                     Deus Vayanne    $2.0 Million
# 14                      SSC Tuatara    $2.0 Million
# 15                      Lotus Evija   $2.0 Million*
# 16              Aston Martin Vulcan    $2.1 Million
# ...
